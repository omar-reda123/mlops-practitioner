# %%
from src.prodml.utils.config import settings
import pandas as pd

# %%
data_raw_path=settings.DATA_RAW_DIR_FILE1
data_raw_path
# Out:
# WindowsPath('D:/projects/mlops-practitioner/data/raw/iris.csv')

# %%
data=pd.read_csv(data_raw_path)
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target'], dtype='str')

# %%
data.shape
# Out:
# (150, 5)

# %%
data['target'].unique()
# Out:
# array([0, 1, 2])
